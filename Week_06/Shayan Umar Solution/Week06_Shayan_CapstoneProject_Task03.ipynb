# %% [markdown]
#  **--------------------------------------------------------Capstone Project – Next Word Prediction-------------------------------------------------------**

# %%
faqs = """
Team Workflow & Responsibilities
This document defines the responsibilities and expectations for each department involved in
project execution at IR Solutions. It ensures clear collaboration, accountability, and efficient
project delivery.
1. General Team Guidelines
● Teammates are supposed to follow all HR policies as defined.
● Maintain professional, ethical, and respectful communication with all teammates
regardless of seniority, age, or gender.
● Every teammate should make sure communication is professional and should be giving
prompt response to other teammates via Slack or any other.
●
● Make sure apps like HCM, Slack, Zoho Mail, and Zoho Sprints etc are installed in phone
and make sure notifications are turned on.
● If a desktop PC is assigned, the teammate must ensure remote access is configured to
manage work when needed. If an office laptop is assigned, it should be kept accessible
at all times to handle tasks remotely or over the weekend when required.
● If a teammate does not take the office laptop home, they must ensure they have access
to a personal PC to handle work in case of emergencies or weekend requirements.
● Ensure your office PC is properly shut down before leaving for the day. If you need to
access it remotely, contact the office boy to turn it on when required. Leaving PCs
powered on after working hours can pose risks to hardware and electrical systems in
case of voltage fluctuations or power issues.
● Attend all meetings and follow-ups punctually and take ownership of your role.
● Always update Zoho Sprints according to the defined process.
● In case of any update or blocker, update the task card from relevant project on Zoho
sprints with comment and request the PM for a meeting. For urgent matters, share the
card link with the PM via Slack.
● Any bugs or issues arising from a teammate’s own work must not impact the overall
project deadline. It is the individual’s responsibility to resolve such problems without
affecting the timelines of other assigned tasks. If necessary, additional time should be
managed outside of regular working hours, either after regular hours or on weekends, to
ensure timely delivery and uphold project commitments.
● PMs and team must manage timelines effectively to prevent any delivery delays.
● Team should collaborate actively after the onboarding meeting to raise any concerns or
technical limitations with each other or PM.
● In case of any conflict or heated conversation, everyone should maintain ethics and a
professional tone as per SOPs. Rudeness, harsh, or any kind of insulting behaviour will
not be tolerated at all, regardless of age, seniority, or experience.
● Always guide and teach other teammates wherever assistance or help is required to
grow as a team.
Good Practices:
● Keep meetings short, focused, and to the point to avoid time wasting.
● Keep your PCs locked when you leave them unattended.
● Make sure to keep your tea or other breaks shorter than 10 minutes.
Bad Practices:
● Multiple tea or other breaks exceeding 10 minutes.
● Irrelevant breaks or discussions in groups.
Regardless of experience or seniority, every team member is treated with equal respect.
No individual is above accountability, and a culture of mutual professionalism and
fairness is maintained across the organization.
2. Project Manager (PM)
● Conduct the project onboarding meeting and share SOW, scope, and timelines.
● Ensure team members understand the project clearly and don’t overcomplicate the
first meeting. Keep it focused.
● Set up Zoho Sprints: create tasks, assign team, and apply milestone tags.
● Manage and prioritize tasks if other project activities overlap. Collaborate with other PMs
to find an optimized solution.
● Review Git repositories regularly to confirm that code is being pushed.
● Authorize deployments to production servers.
● Coordinate team meetings and monitor blockers.
● Collaborate with QA and review the final output.
● Ensure all project updates, sprint comments, and delivery are communicated clearly to
the BD/client.
● Participate in performance evaluations upon project completion.
● Consistently explore emerging technologies, industry trends, and alternative
problem-solving strategies to ensure the team adopts the most effective and up-to-date
solutions.
● Stay updated with trends and solutions to confidently guide projects, anticipate potential
challenges, and propose innovative approaches to overcome development obstacles.
This proactive mindset enhances project success while fostering the team’s professional
growth.
3. Designers
● Attend the project onboarding meeting and understand the project vision.
● Analyze project SOW and raise any confusion or design limitations to the PM.
● Work closely with PM to ensure timely delivery of UI/UX designs.
● Make sure to collaborate efficiently with developers and QA to design only what needs to
be developed, so no workflows or screens are missing.
● Ensure all assets and designs are finalized before handoff to the development team.
Make sure to deliver optimized assets so website/application is not over sized.
● Collaborate with QA to ensure the design is tested and verified before sending it to the
client.
● Designer should have a backup of his work into office PC.
● Make sure to stay updated with industry design standards, screen sizes, and optimized
design workflows.
● Ensure Figma files are secured. If a client shares a Figma file, the designer must create
a copy and continue work within the company’s Figma account, rather than working
directly on the client’s original file.
4. Developers
● Analyze project scope and identify development efforts post-onboarding.
● Raise any technical concerns or limitations early to the PM.
● Regularly push code to Git and keep the PM updated.
● Make sure that the code is standard, optimized and readable with proper naming and
structure followed.
● Only deploy to production after PM approval.
● Keep task cards updated on Zoho Sprints and provide accurate status.
● Join scheduled meetings and scrums. Be proactive in discussing blockers.
● Collaborate with QA to resolve bugs during the testing phase.
5. Quality Assurance (QA)
● Review and test design files before they’re shared with the client.
● Test all project features to ensure development matches the SOW.
● Do not limit yourself to the happy or basic flow of the project; instead, ensure that all
possible scenarios, edge cases, and potential issues are thoroughly considered and
tested.
● Report bugs clearly via Zoho Sprint and keep communication with the PM active.
● It is mandatory for QA to perform Sanity testing even after the project gets deployed onto
the production server. Even QA was passed on the Sandbox.
● Provide QA signoff after all bugs are fixed and project meets the expected quality
standard.
Failure to Comply
Failure to follow the defined policies, procedures, and communication protocols outlined in this
document may result in disciplinary action. Depending on the nature and severity of the
violation, the following consequences may apply:
● Verbal or written warning
● Negative impact on performance evaluation and increments
● Termination of employment
Acknowledgment
I acknowledge that I have read and understood the responsibilities and expectations outlined in
this document. I agree to follow these guidelines and perform my role with professionalism,
accountability, and collaboration.
Zoho Sprints Management Process
This document outlines the complete workflow for managing projects via Zoho Sprints, involving
Project Managers (PMs), Developers, Designers, QA, and Content Writers. It ensures
standardization, accountability, and transparency across all roles.
1. Project Setup by PM
● The Project Manager is responsible for setting up the project board in Zoho Sprints once
the project is awarded.
● The default first status column is Backlog. PM adds initial project cards/tasks to this
column cards that are either pending discussion or not yet ready for execution.
● Only PM will move cards from Backlog to To Do when tasks are ready to be taken up or
vice versa.
● PM also maintains the Project Status (separate from board columns) with the following
stages:
○ Under Discussion: The project has been awarded but is still under discussion
with BD. Team assignment is yet to be finalized.
○ Team Assigned: The team has been allocated to the project by Project Lead,
but formal onboarding by the Project Manager (PM) is still pending.
○ In Progress: The team has been onboarded by the PM. All timelines and tasks
have been defined and set up in Zoho Sprints. Team has started working.
○ Under Review: The project has been signed off by QA and delivered to the
client. It is currently under client review for final approval, or back & forth changes
are going on before final approval from the client.
○ On Hold: The project will be marked as On Hold if there is no client response for
over 2 weeks or if it has been paused based on mutual discussion with the client.
○ Approved: The project has been reviewed and approved by the client. Delivery
is considered complete.
○ Completed: The project is officially closed after the client has confirmed
satisfaction with the delivery, and all associated matters and reviews are
finalized.
Document Version: 1.0 | Last Updated: July 22, 2025
Prepared by: IR Solutions Management
2. Project Details & Team Structure
● In the project description, PM will:
○ Add the main project scope.
○ List all assigned team members with their respective roles (e.g., PM, Dev,
Designer, QA).
● This provides clear visibility into team structure for all teammates.
● PM will be also adding deadline of complete Project under project details on Zoho
sprints.
3. Card Creation & Management
By PM:
● PM will create the majority of cards at project setup based on the Scope of Work (SOW).
● PM will make sure to further break down modules into cards for smooth work
management and tracking. He might take help from project team, tech lead or team lead.
● Every card created must include:
○ Clear title
○ Well-written description of the task
○ Assigned team member
○ Due date (Ideally within 1–2 days, not exceeding 5 days)
○ Relevant milestone or tag.
By Team Members:
● Team members (Developers, QA, Designers, etc.) may create new cards as needed for
tasks, issues, enhancements, or content.
● All created cards must:
Document Version: 1.0 | Last Updated: July 22, 2025
Prepared by: IR Solutions Management
○ Be assigned to the appropriate teammate
○ Have clear titles and due dates
○ Include meaningful descriptions
○ Be tagged properly for visibility
○ Upon moving card to status column, assign to next relevant teammate.
4. Task & Status Flow
Standard Status Columns Used Across Projects:
Backlog, To Do , Bugs, In Progress , Deployed on Sandbox , Under
Review , Ready for Production , Deployed , Sanity Testing , Completed
(Done)
General Task Flow:
● Assigned teammate moves task:
○ From To Do to In Progress when work starts.
● Dev moves the card from In progress to Deployed on Sandbox:
○ Dev assigns card to QA, QA moves the card to Under Review
● QA tests the card, and if it fails:
○ Assigns the same card to the original assignee (Dev/Designer) without creating a
separate bug card.
○ QA moves the card back to In Progress.
○ Comments on the card, tagging assigned @Dev and CC'ing @PM explaining the
issue with text, screenshot, link, video, etc.
● QA tests the card, and if it pass,
○ QA moves the card to "Ready for Production" status, with both the PM and
developer assigned. The PM will then comment on the card to grant the assigned
Developer permission to proceed with deployment on production server .
Document Version: 1.0 | Last Updated: July 22, 2025
Prepared by: IR Solutions Management
5. Bug Lifecycle Management
● If QA finds a new bug:
○ QA will create a new bug card into Bugs status column.
○ Assign it to the relevant teammate.
● Developer moves bug card:
○ From Bugs to In Progress, then to (Ready for test Sandbox
In case of pass or fail, same lifecycle as of task will be followed.
Any bugs or issues in a teammate’s own work should not delay the defined deadline. Such
problems must be resolved, making sure other assigned task deadlines won’t get affected. Even
if have to manage over regular hours, either after 9 to 5 or on weekends to ensure timely
delivery whatever works in the favor of deadlines.
6. Comments, Tags & Communication
● All communication related to task progress, activity, blockers, feedback, or testing must
be done within card comments.
● Use @mentions for individuals (e.g., @Dev, @QA, @PM) to ensure prompt
notifications. Also, explain current stage as well in comments if required.
● Make sure to keep Zoho Sprints app installed and notifications turned on.
● Avoid unnecessary follow-up meetings by maintaining maximum communication inside
Sprints.
● If adding a new tag, it should:
○ Be self-explanatory and short
○ Be communicated to the PM for clarity and easy tracking
Document Version: 1.0 | Last Updated: July 22, 2025
Prepared by: IR Solutions Management
● In case of urgent inquiry about any card, mention relevant teammate along with sharing
the card link into project’s slack channel for prompt response.
7. Card Etiquette Guidelines
● Each card must always be assigned to someone, if team already being assigned.
● Cards must have:
○ Title, description, and due date, and other required relevant details.
● Avoid dragging cards without assigning them or adding updates.
● Communicate any blockers, changes, or clarifications via card comments.
● Keep cards up to date daily to reflect project progress.
● Card once created cannot be deleted. If it’s being deleted by mistake or any issue then
move the card to completed with proper explanation in comments.
Failure to Comply
Failure to follow the defined policies, procedures, and communication protocols outlined in this
document may result in disciplinary action. Depending on the nature and severity of the
violation, the following consequences may apply:
● Verbal or written warning
● Negative impact on performance evaluation and increments
● Termination of employment
Acknowledgment
I acknowledge that I have read and understood the Zoho Sprints Management Process. I
agree to follow the defined workflows, collaborate responsibly, maintain communication within
the platform, and uphold accountability in all assigned tasks.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# Tokenization

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 699

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[13, 197],
#  [13, 197, 130],
#  [46, 38],
#  [46, 38, 343],
#  [46, 38, 343, 1],
#  [46, 38, 343, 1, 130],
#  [46, 38, 343, 1, 130, 4],
#  [46, 38, 343, 1, 130, 4, 198],
#  [46, 38, 343, 1, 130, 4, 198, 17],
#  [46, 38, 343, 1, 130, 4, 198, 17, 131],
#  [46, 38, 343, 1, 130, 4, 198, 17, 131, 344],
#  [46, 38, 343, 1, 130, 4, 198, 17, 131, 344, 345],
#  [46, 38, 343, 1, 130, 4, 198, 17, 131, 344, 345, 8],
#  [5, 199],
#  [5, 199, 93],
#  [5, 199, 93, 77],
#  [5, 199, 93, 77, 57],
#  [5, 199, 93, 77, 57, 22],
#  [5, 199, 93, 77, 57, 22, 200],
#  [5, 199, 93, 77, 57, 22, 200, 94],
#  [5, 199, 93, 77, 57, 22, 200, 94, 201],
#  [5, 199, 93, 77, 57, 22, 200, 94, 201, 78],
#  [5, 199, 93, 77, 57, 22, 200, 94, 201, 78, 4],
#  [5, 199, 93, 77, 57, 22, 200, 94, 201, 78, 4, 346],
#  [5, 47],
#  [67, 202],
#  [67, 202, 13],
#  [67, 202, 13, 132],
#  [2, 79],
#  [2, 79, 27],
#  [2, 79, 27, 347],
#  [2, 79, 27, 347, 3],
#  [2, 79, 27, 347, 3, 58],
#  [2, 79, 27, 347, 3, 58, 19],
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
max_len
# Out:
# 20

# %% [markdown]
# Padding

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  13, 197],
#        [  0,   0,   0, ...,  13, 197, 130],
#        [  0,   0,   0, ...,   0,  46,  38],
#        ...,
#        [  0,   0,   0, ...,  78,   8,  19],
#        [  0,   0,   0, ...,   8,  19,  23],
#        [  0,   0,   0, ...,  19,  23,  41]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (2116, 19)

# %%
y.shape
# Out:
# (2116,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=700)

# %%
y.shape
# Out:
# (2116, 700)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %% [markdown]
# Model Architecture

# %%
model = Sequential()
model.add(Embedding(700, 100, input_shape=(20,)))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(128))
model.add(Dense(700, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (None, 20, 100)        │        70,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 20, 256)        │       365,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 700)            │        90,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,988 (2.76 MB)
#  Trainable params: 722,988 (2.76 MB)
# ...

# %% [markdown]
# Training the model

# %%
model.fit(X,y,epochs=150)
# Out:
# Epoch 1/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.0338 - loss: 6.3138
# Epoch 2/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.0438 - loss: 5.8041
# Epoch 3/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - accuracy: 0.0494 - loss: 5.7778
# Epoch 4/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 11s 105ms/step - accuracy: 0.0485 - loss: 5.7687
# Epoch 5/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.0470 - loss: 5.6523
# Epoch 6/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - accuracy: 0.0459 - loss: 5.5552
# Epoch 7/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.0488 - loss: 5.4831
# Epoch 8/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.0490 - loss: 5.4324
# Epoch 9/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.0540 - loss: 5.2888
# Epoch 10/150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.0664 - loss: 5.2569
# Epoch 11/150
# ...

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Time')
plt.legend()
plt.show()

# %% [markdown]
# Inferencing using the trained model

# %%
import time
import numpy as np
text = "General Task Flow"

for i in range(20):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=20, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# General Task Flow of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# General Task Flow of the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# General Task Flow of the project
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# General Task Flow of the project instead
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# General Task Flow of the project instead ensure
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# General Task Flow of the project instead ensure that
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# General Task Flow of the project instead ensure that all
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# General Task Flow of the project instead ensure that all delivery
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# General Task Flow of the project instead ensure that all delivery delays
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# General Task Flow of the project instead ensure that all delivery delays proper
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# ...

# %% [markdown]
# Saving the model and tokenizer

# %%
# Save model without optimizer state
model.save("next_word_generator.keras", include_optimizer=False)

# %%
import pickle

with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)
